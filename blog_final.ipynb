# %%
# 시작전 구글과 tistory 로그인!

import requests
from bs4 import BeautifulSoup

import time
import re
import pandas as pd

import pyautogui as pg
import keyboard
import clipboard
import time
import random
import csv

# %%
headers = {'User-agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"}
url = "https://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&cornerNo=1"
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'lxml')
food_list = soup.find('div', class_="best_prd_box").find_all('li')

# %%
max_n = 10
cur_n = 0
file_name = 'history.csv'
keyword = None


            
# 랜덤으로 생성 names과 urls로 구분

num = random.randint(0,30)
urls =[]
names = []
for food in food_list[num:num+10]:
    urls.append(food.a['href'])
    names.append(food.p.text.strip())


# 전처리

refined_name = []
for i in names:
    bucket =[]
    for j in i.split():
        if j[0].isalpha() and len(j) > 1:
            bucket.append(j)
    refined_name.append(' '.join(bucket))

# 최근 5개의 블로그 글 까지만 중복되지 않도록 함
file_name = 'history.csv'
history_list = []
with open(file_name, 'r', newline='', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for row in csv_reader:
        history_list.append(row[0])


# 사진이 없을 경우 다른 상품으로 대체

for i in range(10):

    today_name = refined_name[i]
    today_url = urls[i]

    res = requests.get(today_url)
    soup = BeautifulSoup(res.text, 'html.parser')
    keyword = soup.find('meta', attrs={'name':'keyword'})['content'].strip().split('>')[-1]

    # '기타' 문자 제거
    parts = keyword.split()
    if "기타" in parts:
        parts.remove("기타")
        keyword = " ".join(parts)
    
    else:
        pass
    
    # 최근 5개의 글과 중복될 경우 스킵
    if keyword in history_list[-5:]:
        continue

    # 나무위키 이용
    res = requests.get(f'https://namu.wiki/w/{keyword}',headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')

    if soup.find('img', class_='vIrqy6Di'):

        if soup.find('img', class_='vIrqy6Di')['alt'] == '다른 뜻 아이콘':
            print('사진 없음')
            continue

        print(keyword)

        try: 
            img = 'https:' + soup.find('img', class_='vIrqy6Di')['data-src']
            print(img)
            print('done')
            break

        except Exception as e:
            print(e, 'haha')
            continue
    else:
        continue
# Out:
# 사진 없음
# 사진 없음
# 닭가슴살
# https://i.namu.wiki/i/p0qD7OnS7iw_4lTqvKlGCxJWv3a9z2_c7mFiat1oIG6a8Btt8At_l-UcquMUgRkcXKEs0WPNqpa5VIjdhk44mPoKVpvGR3X3zHfmfUyVuREyE-q3LY6c8Y1Zb9elFvTQ1zPRWTK3VWGUnemTyc1ypQ.svg
# done

# %%
# 사진이 없을 경우 다른 상품으로 대체

for i in range(10):

    today_name = refined_name[i]
    today_url = urls[i]

    res = requests.get(today_url)
    soup = BeautifulSoup(res.text, 'html.parser')
    keyword = soup.find('meta', attrs={'name':'keyword'})['content'].strip().split('>')[-1]

    # '기타' 문자 제거
    parts = keyword.split()
    if "기타" in parts:
        parts.remove("기타")
        keyword = " ".join(parts)
    else:
        pass
    
    # 최근 5개의 글과 중복될 경우 스킵
    if keyword in history_list[-5:]:
        continue

    # 나무위키 이용
    res = requests.get(f'https://namu.wiki/w/{keyword}',headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')

    if soup.find('img', class_='vIrqy6Di'):

        if soup.find('img', class_='vIrqy6Di')['alt'] == '다른 뜻 아이콘':
            print('사진 없음')
            continue

        print(keyword)

        try: 
            img = 'https:' + soup.find('img', class_='vIrqy6Di')['data-src']
            print(img)
            print('done')
            break

        except Exception as e:
            print(e, 'haha')
            continue
    else:
        continue
# Out:
# 사진 없음
# 사진 없음
# 닭가슴살
# https://i.namu.wiki/i/p0qD7OnS7iw_4lTqvKlGCxJWv3a9z2_c7mFiat1oIG6a8Btt8At_l-UcquMUgRkcXKEs0WPNqpa5VIjdhk44mPoKVpvGR3X3zHfmfUyVuREyE-q3LY6c8Y1Zb9elFvTQ1zPRWTK3VWGUnemTyc1ypQ.svg
# done

# %%
# 크롬이미지 확인 및 선택
chrome = pg.locateOnScreen('./images/chrome.png',confidence = 0.9)
pg.click(chrome)

loading = None
while not loading:
    loading = pg.locateOnScreen('./images/loading.png',confidence = 0.7)
    time.sleep(0.3)

# gpt이미지
gpt = pg.locateOnScreen('./images/chatgpt.png',confidence = 0.6)
pg.click(gpt)


# 화면 크기 150%
start = None
while not start:
    start = pg.locateOnScreen('./images/start.png',confidence = 0.6)
    time.sleep(0.3)

time.sleep(random.uniform(0.5,0.8))

pg.click(start)

time.sleep(random.uniform(1,2))

# 질문
text = f'({today_name})이 것의 메인 재료로 블로그 글을 작성해줘 (제목: )과 (본문: )형식으로 나누고 효능과 부작용 기타 지식 해시태그를 1500자 분량으로 적어줘'
clipboard.copy(text)
pg.hotkey('ctrl','v')
pg.press('enter')

# 대답이 나올 때까지 대기
where = None
while not where:
    where = pg.locateOnScreen('./images/done.png')
    time.sleep(0.5)

# 상단 이동

pg.click(x=1058, y=339)
time.sleep(0.7)
pg.click(x=1058, y=339)

pg.press('home')
time.sleep(2)

pg.press('home')
time.sleep(4)

copy = None
while not copy:
    copy = pg.locateOnScreen('./images/copy.png')
    time.sleep(0.3)

pg.click(copy)

text = clipboard.paste()

# 제목, 타이틀, 해시태그 지정
try:
    title = re.search(r'제목: "(.*)"', text).group(1)
except:
    title = re.search(r'제목: (.*)', text).group(1)
match = re.search(r'본문:(.*)', text, re.DOTALL)

if match:
    content, hashtag = match.group(1).split('#', 1)
    hashtag = '#'+hashtag
    hashtag = hashtag[:hashtag.rfind('#')-1]
    content = content[:content.rfind('.')+1]

time.sleep(3)

# %%
content
# Out:
# '\r\n하림 FreshUP 닭볶음탕용 닭가슴살, 근위, 닭다리살은 건강한 식사를 추구하는 이들에게 최적의 선택입니다. 이 제품은 맛과 영양을 결합하여 당신의 식사를 더욱 풍부하게 만들어줍니다. 이번 글에서는 이 제품의 주요 재료에 대해 자세히 살펴보고, 그것의 효능과 부작용, 그리고 기타 유용한 지식을 다뤄보겠습니다.\r\n\r\n**효능:**\r\n\r\n1. **닭가슴살**:\r\n   - 단백질 풍부: 닭가슴살은 고단백, 저지방 식품으로 운동을 하거나 다이어트 중인 사람들에게 이상적입니다.\r\n   - 비타민 B6: 체내 에너지 생산 및 신경 기능에 도움을 줍니다.\r\n   - 단백질 품질: 근위와 함께 섭취하면 신체의 단백질 생성을 지원하고 근육 무게 유지에 도움이 됩니다.\r\n\r\n2. **근위 (스파이스)**:\r\n   - 항산화 성분: 근위는 항산화 물질을 풍부하게 함유하고 있어 자유 라디칼의 손상으로부터 세포를 보호합니다.\r\n   - 항염증 작용: 관절 염증을 완화하고, 소화 문제를 개선하는데 도움이 될 수 있습니다.\r\n   - 향신료로 사용: 맛을 풍부하게 하며, 요리에 깊은 풍미를 더합니다.\r\n\r\n3. **닭다리살**:\r\n   - 미네랄 공급: 철, 아연, 인 등의 미네랄을 풍부하게 함유하고 있어 영양 균형을 유지하는 데 도움을 줍니다.\r\n   - 다양한 요리: 다양한 조리 방법으로 사용 가능하며, 다양한 요리를 즐기기에 이상적입니다.\r\n\r\n**부작용:**\r\n\r\n하림 FreshUP 제품은 대체로 안전하게 섭취할 수 있지만, 알레르기 반응이 있을 수 있으므로 알레르기 유발 식품에 주의해야 합니다. 또한 적절한 조리 및 보관을 통해 식품 안전을 유지해야 합니다.\r\n\r\n**기타 지식:**\r\n\r\n- 신선한 식재료: 하림 FreshUP 제품은 신선한 식재료로 제조되어 풍부한 영양을 제공합니다.\r\n- 다양한 레시피: 닭가슴살, 근위, 닭다리살은 다양한 요리에 사용할 수 있어 요리의 창의성을 높일 수 있습니다.\r\n- 지속가능한 생산: 하림은 지속 가능한 식품 생산을 촉진하고 환경에 대한 책임을 다하고 있습니다.'

# %%
# t story url
clipboard.copy('https://jamis.tistory.com/manage/newpost/?type=post&returnURL=%2Fmanage%2Fposts%2F')

# 새 창 열기
pg.click(pg.locateOnScreen('./images/new_tab.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))

pg.hotkey('ctrl','v')

time.sleep(random.uniform(0.3,0.7))

pg.press('enter')

time.sleep(random.uniform(0.8,1))


# 작성 중이던 것이 있는가
time.sleep(1)
if pg.locateOnScreen('./images/cancle.png', confidence=0.9):
    pg.click(pg.locateOnScreen('./images/cancle.png', confidence=0.9))

time.sleep(random.uniform(0.3,0.7))


pg.press('tab')

# 새 창 열기
pg.click(pg.locateOnScreen('./images/new_tab.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))

clipboard.copy(img)
pg.hotkey('ctrl', 'v')
pg.press('enter')

time.sleep(random.uniform(0.5,0.7))

pg.click(x=989, y=601)
time.sleep(0.1)

pg.hotkey('ctrl', 'c')
time.sleep(0.1)

pg.hotkey('ctrl', 'w')
time.sleep(0.1)

pg.hotkey('ctrl', 'v')
time.sleep(2)

pg.click(pg.locateOnScreen('./images/explain.png', confidence=0.9))
clipboard.copy(keyword+' (나무위키)')
pg.hotkey('ctrl', 'v')
pg.press('enter')

time.sleep(random.uniform(0.5,0.7))


pg.press('tab')

# 해시태그 작성
clipboard.copy(hashtag)
pg.hotkey('ctrl', 'v')

# 카테고리 설정
pg.click(pg.locateOnScreen('./images/category.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))

pg.click(pg.locateOnScreen('./images/food.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))


# 마크다운 설정
pg.click(pg.locateOnScreen('./images/select_mode.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))
pg.click(pg.locateOnScreen('./images/select_markdown.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))
pg.click(pg.locateOnScreen('./images/ok.png', confidence=0.9))
time.sleep(random.uniform(0.5,0.7))


# 작성 탭으로 이동
for _ in range(4):
    pg.press('tab')
    time.sleep(0.2)

# 타이틀 작성
clipboard.copy(title)
pg.hotkey('ctrl', 'v')

for _ in range(2):
    pg.press('tab')
    time.sleep(0.4)
pg.press('end')
pg.press('enter')
pg.press('enter')


# 컨텐츠 작성
clipboard.copy(content)
pg.hotkey('ctrl', 'v')
pg.press('tab')

time.sleep(random.uniform(0.3,0.7))

# 작성 완료 버튼
pg.click(pg.locateOnScreen('./images/complete.png', confidence=0.9))
time.sleep(random.uniform(0.3,0.7))

# 태그 설정
pg.click(pg.locateOnScreen('./images/no_select.png', confidence=0.9))
time.sleep(random.uniform(0.3,0.7))
pg.click(pg.locateOnScreen('./images/lifeinfo.png', confidence=0.9))
time.sleep(random.uniform(0.3,0.7))

# 발행 완료
pg.click(pg.locateOnScreen('./images/final.png', confidence=0.9))
time.sleep(random.uniform(0.3,0.7))



    
# 작업이 완료되면 history에 저장, 같은 글을 다시 쓰지 않기 위해

with open(file_name, 'a', newline='', encoding='utf-8') as f:
    csv_writer = csv.writer(f)
    if keyword is not None:
        csv_writer.writerow([f'{keyword}'])

print('Done!')
# Out:
# Done!
